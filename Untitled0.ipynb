# %%
pip install mstrio-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mstrio-py
#   Downloading mstrio-py-11.3.4.101.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 24.7 MB/s
# Collecting notebook>=6.4.5
#   Downloading notebook-6.4.11-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 48.5 MB/s
# Collecting requests<2.26,>=2.25
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 8.4 MB/s
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 73.2 MB/s
# Collecting requests_futures<1.1,>=1.0.0
#   Downloading requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# Collecting pandas<1.3,>=1.1.5
#   Downloading pandas-1.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 18.5 MB/s
# Requirement already satisfied: numpy<1.22,>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from mstrio-py) (1.21.6)
# Requirement already satisfied: tqdm<4.70,>=4.41 in /usr/local/lib/python3.7/dist-packages (from mstrio-py) (4.64.0)
# Collecting packaging<21,>=20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.5 MB/s
# Collecting dictdiffer<0.9,>=0.8.1
#   Downloading dictdiffer-0.8.1-py2.py3-none-any.whl (16 kB)
# Collecting stringcase<1.3,>=1.2
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
# Requirement already satisfied: Jinja2<3.0,>=2.11 in /usr/local/lib/python3.7/dist-packages (from mstrio-py) (2.11.3)
# Collecting lxml>=4.7.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 49.6 MB/s
# Collecting jupyter_contrib_nbextensions<0.6,>=0.5.1
#   Downloading jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9 MB)
#      |████████████████████████████████| 20.9 MB 1.1 MB/s
# Requirement already satisfied: ipywidgets<8,>=7.5.1 in /usr/local/lib/python3.7/dist-packages (from mstrio-py) (7.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (1.1.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (5.5.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (5.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (4.10.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (3.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7.5.1->mstrio-py) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->mstrio-py) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->mstrio-py) (5.1.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (0.7.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.11->mstrio-py) (2.0.1)
# Collecting jupyter-latex-envs>=1.3.8
#   Downloading jupyter_latex_envs-1.4.6.tar.gz (861 kB)
#      |████████████████████████████████| 861 kB 50.2 MB/s
# Requirement already satisfied: nbconvert>=4.2 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (5.6.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (4.10.0)
# Collecting jupyter-nbextensions-configurator>=0.4.0
#   Downloading jupyter_nbextensions_configurator-0.4.1.tar.gz (479 kB)
#      |████████████████████████████████| 479 kB 37.6 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (3.13)
# Collecting jupyter-highlight-selected-word>=0.1.1
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter-contrib-core>=0.3.3
#   Downloading jupyter_contrib_core-0.3.3-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (2.15.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (4.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (4.11.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.5.1->mstrio-py) (3.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from notebook>=6.4.5->mstrio-py) (0.13.3)
# Collecting tornado>=4.0
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 46.9 MB/s
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.7/dist-packages (from notebook>=6.4.5->mstrio-py) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from notebook>=6.4.5->mstrio-py) (23.0.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from notebook>=6.4.5->mstrio-py) (0.14.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/dist-packages (from notebook>=6.4.5->mstrio-py) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=6.4.5->mstrio-py) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->mstrio-py) (2.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging<21,>=20.9->mstrio-py) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3,>=1.1.5->mstrio-py) (2022.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets<8,>=7.5.1->mstrio-py) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<2.26,>=2.25->mstrio-py) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<2.26,>=2.25->mstrio-py) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<2.26,>=2.25->mstrio-py) (2022.5.18.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.3->notebook>=6.4.5->mstrio-py) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.7/dist-packages (from argon2-cffi->notebook>=6.4.5->mstrio-py) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.4.5->mstrio-py) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.4.5->mstrio-py) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions<0.6,>=0.5.1->mstrio-py) (0.5.1)
# Building wheels for collected packages: mstrio-py, jupyter-latex-envs, jupyter-nbextensions-configurator, stringcase
#   Building wheel for mstrio-py (setup.py) ... done
#   Created wheel for mstrio-py: filename=mstrio_py-11.3.4.101-py3-none-any.whl size=1283901 sha256=f35e1c19490ccfd2938a01655fa65dd6cc68002343094db82449c30cb6f8e0ba
#   Stored in directory: /root/.cache/pip/wheels/52/b1/cf/0278cd8138da1cb118e342fcd9c280d7df94a3c5c47cde41c4
#   Building wheel for jupyter-latex-envs (setup.py) ... done
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963415 sha256=0c45594d217f4c4e06083e38d14f50cc8eab8b8fca318f90b9e12dafcf8f71cf
#   Stored in directory: /root/.cache/pip/wheels/a0/95/26/4cf34fb92765c95fb7851fd447511594bcc3a50e504bd09af9
#   Building wheel for jupyter-nbextensions-configurator (setup.py) ... done
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465843 sha256=17666ff2489394eb60ac8e7d0e91d82e35a84069366f7cdc4d03d520209484dc
#   Stored in directory: /root/.cache/pip/wheels/8d/c4/b5/e4b61f624036f83566580d61f24af7b73180b1361ee1ab3722
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3587 sha256=108e6ce0546f144f1c8eb6815c0aaa6070140aa77b3f5fec64cde4dd473838b8
#   Stored in directory: /root/.cache/pip/wheels/86/ab/a3/a8fa7e0a07e80f547e03468c03827f8257f7339327986faed1
# Successfully built mstrio-py jupyter-latex-envs jupyter-nbextensions-configurator stringcase
# Installing collected packages: tornado, notebook, urllib3, jupyter-contrib-core, requests, lxml, jupyter-nbextensions-configurator, jupyter-latex-envs, jupyter-highlight-selected-word, stringcase, requests-futures, pandas, packaging, jupyter-contrib-nbextensions, dictdiffer, mstrio-py
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.3.1
#     Uninstalling notebook-5.3.1:
#       Successfully uninstalled notebook-5.3.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires notebook~=5.3.0; python_version >= "3.0", but you have notebook 6.4.11 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.25.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed dictdiffer-0.8.1 jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.1 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.6 jupyter-nbextensions-configurator-0.4.1 lxml-4.8.0 mstrio-py-11.3.4.101 notebook-6.4.11 packaging-20.9 pandas-1.2.5 requests-2.25.1 requests-futures-1.0.0 stringcase-1.2.0 tornado-6.1 urllib3-1.26.9

# %%
from mstrio.connection import Connection
import getpass

# %%
base_url = "http://localhost:8080/MicroStrategyLibrary/api"
mstr_username = "Administrator"
mstr_password = getpass.getpass("Password: ")
project_name = "MicroStrategy Tutorial"
conn = Connection(base_url, mstr_username, mstr_password, project_name)

# %% [markdown]
# tipos conexiones

# %% [markdown]
# Standard

# %%
conn = Connection(base_url, mstr_username, mstr_password, project_name=project_name, login_mode=16)

# %% [markdown]
# Strandard con Token

# %%
conn = Connection(base_url, identity_token=identity_token, project_name=project_name)

# %% [markdown]
# Certificado SSL

# %%
conn = Connection(base_url, mstr_username, mstr_password, project_name = project_name, ssl_verify=False)

# %%
conn = Connection(base_url, mstr_username, mstr_password, project_id=project_id, ssl_verify=True)

# %%
conn = Connection(base_url, mstr_username, mstr_password, project_id=project_id, certificate_path="C:/path/to/your/certificate.pem")
